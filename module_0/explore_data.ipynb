# %%
import pandas as pd
pd.read_parquet("infra/driver_stats.parquet")
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 0    2022-02-27 15:00:00+00:00       1005   0.142214  0.408987
# 1    2022-02-27 16:00:00+00:00       1005   0.349267  0.734021
# 2    2022-02-27 17:00:00+00:00       1005   0.358805  0.366804
# 3    2022-02-27 18:00:00+00:00       1005   0.611828  0.773883
# 4    2022-02-27 19:00:00+00:00       1005   0.156503  0.966413
# ...                        ...        ...        ...       ...
# 1802 2022-03-14 11:00:00+00:00       1001   0.667961  0.211051
# 1803 2022-03-14 12:00:00+00:00       1001   0.209861  0.672022
# 1804 2022-03-14 13:00:00+00:00       1001   0.215754  0.791849
# 1805 2022-03-14 14:00:00+00:00       1001   0.404588  0.407571
# 1806 2021-04-12 07:00:00+00:00       1001   0.521149  0.751659
#
#                      created         day  miles_driven  daily_miles_driven
# 0    2022-03-14 15:21:25.842  2022-02-27     24.817618          150.587752
# ...

# %%
import pandas as pd

df = pd.read_parquet("infra/driver_stats.parquet")

# Re-save with index=False to avoid hidden index column
df.to_parquet("infra/driver_stats_clean.parquet", index=False)

# %%
import pandas as pd
pd.read_parquet("infra/driver_stats_clean.parquet")
# Out:
# ',event_timestamp,driver_id,conv_rate,acc_rate,created,day,miles_driven,daily_miles_driven\n0,2022-02-27 15:00:00+00:00,1005,0.1422142,0.40898654,2022-03-14 15:21:25.842,2022-02-27,24.817617766449352,150.58775174455425\n1,2022-02-27 16:00:00+00:00,1005,0.34926686,0.7340207,2022-03-14 15:21:25.842,2022-02-27,8.293351600986387,150.58775174455425\n2,2022-02-27 17:00:00+00:00,1005,0.35880527,0.36680403,2022-03-14 15:21:25.842,2022-02-27,8.316671676732962,150.58775174455425\n3,2022-02-27 18:00:00+00:00,1005,0.6118282,0.7738834,2022-03-14 15:21:25.842,2022-02-27,10.56645783769355,150.58775174455425\n4,2022-02-27 19:00:00+00:00,1005,0.15650299,0.9664127,2022-03-14 15:21:25.842,2022-02-27,15.66433150477562,150.58775174455425\n5,2022-02-27 20:00:00+00:00,1005,0.6193893,0.9492523,2022-03-14 15:21:25.842,2022-02-27,1.6329351629409294,150.58775174455425\n6,2022-02-27 21:00:00+00:00,1005,0.69430834,0.6711707,2022-03-14 15:21:25.842,2022-02-27,42.90726773951191,150.58775174455425\n7,2022-02-27 22:
# ...
